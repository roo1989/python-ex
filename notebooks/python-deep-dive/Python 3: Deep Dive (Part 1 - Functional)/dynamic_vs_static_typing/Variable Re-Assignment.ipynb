# %%
a = 10

# %%
hex(id(a))
# Out:
# '0x10051ea50'

# %%
type(a)
# Out:
# int

# %%
a = 15

# %%
hex(id(a)) 
# Different memory address than before even though the variable name is the same,
# it's now referencing another object in memory
# Out:
# '0x10051eaf0'
